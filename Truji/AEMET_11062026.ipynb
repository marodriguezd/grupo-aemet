# %% [markdown]
# # Proyecto AEMET - Resumen de Extracción, Transformación y Carga (ETL) de Datos Climatológicos
# Este notebook consolida y explica paso a paso todo el flujo de trabajo desarrollado para interactuar con la API de la AEMET (Agencia Estatal de Meteorología), procesar y limpiar la información, y exportar un dataset histórico listo para análisis o entrenamiento de modelos.
#
# ---
#
# ## 📋 Objetivos de este Notebook
# 1. **Autenticación e Integración:** Conectar con la API de AEMET OpenData utilizando una API Key almacenada de forma segura en un archivo `.env` local.
# 2. **Descarga del Catálogo de Estaciones:** Obtener y mostrar el maestro de estaciones meteorológicas operativas en España.
# 3. **Consulta de Datos de Prueba:** Descargar un subconjunto de datos diarios para una estación específica en un rango de fechas reducido para validar la conexión.
# 4. **Limpieza y Modelado de Datos (ETL):** Procesar la respuesta JSON de la API, reemplazando caracteres incorrectos, convirtiendo tipos de datos (strings a floats con coma, datetime) y manejando nulos de forma robusta.
# 5. **Descarga Masiva e Histórica:** Implementar un bucle para extraer datos históricos de los últimos años, gestionando de forma proactiva los límites de velocidad (rate limiting) de la API mediante retardos estratégicos.
# 6. **Exportación de Datos:** Consolidar el dataset completo en archivos Excel y CSV en el espacio local del usuario.
# 7. **Visualización Resumen:** Crear un gráfico de control que muestre la evolución del clima a lo largo del tiempo para validar los datos visualmente.

# %%
# Importamos las librerías necesarias
import os
import zipfile
import sys
import time
import json
import calendar
import subprocess
from datetime import datetime, timedelta
from pathlib import Path
import pandas as pd
import numpy as np
import requests
from dotenv import load_dotenv
from IPython.display import display


# Tuve que meter este parche raro de zipfile porque me daba error al cerrar archivos excel en python 3.14+
# 'ValueError: seek of closed file'. Lo saqué de StackOverflow y le pongo un check para que no se raye si ejecuto la celda dos veces.
if not hasattr(zipfile.ZipFile, '_patched'):
    try:
        _orig_zipfile_del = zipfile.ZipFile.__del__
        def _safe_zipfile_del(self):
            try:
                _orig_zipfile_del(self)
            except (ValueError, AttributeError):
                pass
        zipfile.ZipFile.__del__ = _safe_zipfile_del
        zipfile.ZipFile._patched = True
    except AttributeError:
        pass


# Función para comprobar e instalar automáticamente las librerías si no están instaladas
def asegurar_libreria(nombre_paquete, nombre_import=None):
    if nombre_import is None:
        nombre_import = nombre_paquete
    try:
        __import__(nombre_import)
    except ImportError:
        print(f"No tienes instalado '{nombre_paquete}'. Instalando con pip...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", nombre_paquete])
        print(f"'{nombre_paquete}' instalada correctamente.")

asegurar_libreria("openpyxl")
asegurar_libreria("matplotlib", "matplotlib.pyplot")
asegurar_libreria("seaborn")

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")

print("Librerías listas!")
# Out:
# Librerías listas!

# %% [markdown]
# ## Paso 1: Configuración del Entorno y Carga de Variables Seguras
#
# Para evitar exponer credenciales en el código fuente, la API Key de AEMET se almacena en el archivo `.env` de esta carpeta. Usamos la biblioteca `python-dotenv` para cargar el entorno de forma segura, apuntando específicamente al directorio de este notebook.

# %%
# Buscamos el archivo .env para la API KEY de AEMET
BASE_DIR = Path().resolve()
env_path = BASE_DIR / '.env'

print("Buscando el archivo .env en:", env_path)

if env_path.exists():
    load_dotenv(dotenv_path=env_path)
    print("El archivo .env se ha cargado.")
else:
    print("Ojo: No se encontró el .env en esta carpeta. Probamos con el entorno general.")
    load_dotenv()

# Sacamos la API Key
API_KEY = os.getenv('AEMET_API_KEY')
if not API_KEY:
    raise RuntimeError('No se encontró AEMET_API_KEY en las variables de entorno.')
else:
    # Mostramos un trozo por seguridad
    print(f"API Key encontrada: {API_KEY[:6]}...{API_KEY[-6:]}")
# Out:
# Buscando el archivo .env en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\.env
# El archivo .env se ha cargado.
# API Key encontrada: eyJhbG...sjBWr4

# %% [markdown]
# ## Paso 2: El Protocolo de Conexión de AEMET OpenData
#
# La API de AEMET funciona bajo un modelo de **"doble llamada"**:
# 1. Enviamos nuestra consulta con la clave `api_key` en las cabeceras (headers) de la solicitud HTTP GET.
# 2. AEMET valida la solicitud y nos responde con un JSON de metadatos que contiene una URL temporal en el campo `datos`.
# 3. Hacemos una segunda solicitud `GET` a esa URL temporal (esta vez sin cabeceras de autorización) para descargar los datos reales del sensor en formato JSON.
#
# Definimos el diccionario de cabeceras que utilizaremos en la primera llamada de autenticación.

# %%
# Preparamos las cabeceras para la petición
headers = {
    'cache-control': "no-cache",
    'api_key': API_KEY,
    'accept': "application/json"
}

print("Cabeceras listas para usar.")
# Out:
# Cabeceras listas para usar.

# %% [markdown]
# ## Paso 3: Obtener el Inventario Completo de Estaciones Climatológicas
#
# Para realizar cualquier consulta histórica, necesitamos conocer el identificador único (`indicativo` o `idema`) de la estación meteorológica. El endpoint `/api/valores/climatologicos/inventarioestaciones/todasestaciones` nos devuelve el catálogo completo de las estaciones activas en España.

# %%
# Función para traer el listado de todas las estaciones
def obtener_inventario_estaciones():
    url_base = "https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones"
    
    print("Pidiendo el inventario a la API:", url_base)
    try:
        response = requests.get(url_base, headers=headers, timeout=30)
        if response.status_code == 200:
            meta_datos = response.json()
            print(f"Respuesta API: {meta_datos.get('descripcion')} (Estado: {meta_datos.get('estado')})")
            
            if meta_datos.get('estado') == 200:
                url_datos = meta_datos.get('datos')
                print("Tenemos enlace temporal, descargando los datos reales...")
                
                # Segunda llamada
                datos_response = requests.get(url_datos, timeout=30)
                if datos_response.status_code == 200:
                    return datos_response.json()
                else:
                    print("Error al descargar datos finales, código:", datos_response.status_code)
            else:
                print("Error en AEMET:", meta_datos.get('descripcion'))
        else:
            print("Error de red en la primera llamada:", response.status_code)
    except Exception as e:
        print("Ha ocurrido una excepción:", e)
    return None

# Probamos a traer las estaciones
estaciones = obtener_inventario_estaciones()

if estaciones:
    print(f"Total estaciones cargadas: {len(estaciones)}")
    df_estaciones = pd.DataFrame(estaciones)
    print("Primeras 5 estaciones:")
    
else:
    print("No se pudo obtener el inventario. Revisa la clave API.")
df_estaciones.head(5)
# Out:
# Pidiendo el inventario a la API: https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones
# Respuesta API: exito (Estado: 200)
# Tenemos enlace temporal, descargando los datos reales...
# Total estaciones cargadas: 920
# Primeras 5 estaciones:
#    latitud      provincia altitud indicativo               nombre indsinop  \
# 0  394924N  ILLES BALEARS     490      B013X        ESCORCA, LLUC    08304
# 1  394744N       BALEARES       5      B051A       SÓLLER, PUERTO    08316
# 2  394121N  ILLES BALEARS      60      B087X          BANYALBUFAR
# 3  393446N       BALEARES      52      B103B   ANDRATX - SANT ELM
# 4  393305N       BALEARES      50      B158X  CALVIÀ, ES CAPDELLÀ
#
#   longitud
# 0  025309E
# 1  024129E
# 2  023046E
# 3  022208E
# 4  022759E

# %% [markdown]
# ## Paso 4: Consulta de Prueba de Valores Climatológicos Diarios
#
# Para verificar el flujo de descarga de datos de sensores diarios, consultaremos los datos del 1 al 15 de mayo de 2026 para la estación de **Palma de Mallorca (Puerto)** (indicativo o idema: `"B228"`).
#
# El formato del endpoint requerido es:
# `/api/valores/climatologicos/diarios/datos/fechaini/{fecha_ini}/fechafin/{fecha_fin}/estacion/{idema}`

# %%
# Petición para una sola estación (para pruebas)
def obtener_valores_climaticos(fecha_ini_utc, fecha_fin_utc, idema):
    url_base = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fecha_ini_utc}/fechafin/{fecha_fin_utc}/estacion/{idema}"
    
    try:
        response = requests.get(url_base, headers=headers, timeout=30)
        if response.status_code == 200:
            meta_datos = response.json()
            if meta_datos.get('estado') == 200:
                url_final = meta_datos.get('datos')
                datos_response = requests.get(url_final, timeout=30)
                if datos_response.status_code == 200:
                    return datos_response.json()
                else:
                    print("Error descargando los datos climatológicos:", datos_response.status_code)
            else:
                return None
        else:
            print("Error de red:", response.status_code)
    except Exception as e:
        print("Excepción al consultar clima:", e)
    return None


# Petición para todas las estaciones con reintentos y esperas (backoff) si falla la API
def obtener_valores_climaticos_todas(fecha_ini_utc, fecha_fin_utc, max_retries=15, base_delay=5.0):
    url_base = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fecha_ini_utc}/fechafin/{fecha_fin_utc}/todasestaciones"
    delay = base_delay
    for intento in range(max_retries):
        try:
            response = requests.get(url_base, headers=headers, timeout=30)
            
            # Si no tenemos permiso o no existe el endpoint, paramos
            if response.status_code in [401, 403, 404]:
                print(f"Error grave {response.status_code}, no se puede reintentar.")
                return None
                
            if response.status_code == 200:
                meta_datos = response.json()
                estado = meta_datos.get('estado')
                
                if estado == 200:
                    url_final = meta_datos.get('datos')
                    datos_response = requests.get(url_final, timeout=30)
                    if datos_response.status_code == 200:
                        return datos_response.json()
                    elif datos_response.status_code in [401, 403, 404]:
                        print(f"Error grave en datos {datos_response.status_code}, no reintentamos.")
                        return None
                    else:
                        print(f"Intento {intento+1} fallido al descargar datos: {datos_response.status_code}")
                elif estado in [401, 403, 404]:
                    print(f"Error API: Estado {estado}: {meta_datos.get('descripcion')}. No se reintentará.")
                    return None
                elif estado == 429:
                    print(f"Intento {intento+1}: La API dice Estado 429 (Límite superado).")
                else:
                    print(f"Intento {intento+1}: API devolvió Estado {estado}: {meta_datos.get('descripcion')}")
            elif response.status_code == 429:
                print(f"Intento {intento+1}: HTTP 429 (Muchas peticiones).")
            else:
                print(f"Intento {intento+1}: Código de red {response.status_code}")
                
        except Exception as e:
            print(f"Intento {intento+1}: Error de red/conexión: {e}")
            
        if intento < max_retries - 1:
            print(f"Esperando {delay} segundos antes de reintentar...")
            time.sleep(delay)
            delay *= 2.0
            
    print(f"No se pudo descargar el bloque tras {max_retries} intentos.")
    return None

# Hacemos una prueba con Palma de Mallorca (B228)
idema_prueba = "B228"
ini_prueba = "2026-05-01T00:00:00UTC"
fin_prueba = "2026-05-15T00:00:00UTC"

print("Probando descarga para Palma de Mallorca...")
climaticos_prueba = obtener_valores_climaticos(ini_prueba, fin_prueba, idema_prueba)

if climaticos_prueba:
    print(f"¡Funciona! Hemos descargado {len(climaticos_prueba)} filas diarias.")
    print("Ejemplo del primer registro en crudo:")
    print(json.dumps(climaticos_prueba[0], indent=2, ensure_ascii=False))
else:
    print("No se han recibido datos. Revisa fechas y tu API Key.")
# Out:
# Probando descarga para Palma de Mallorca...
# ¡Funciona! Hemos descargado 15 filas diarias.
# Ejemplo del primer registro en crudo:
# {
#   "fecha": "2026-05-01",
#   "indicativo": "B228",
#   "nombre": "PALMA, PUERTO",
#   "provincia": "BALEARES",
#   "altitud": "3",
#   "tmed": "19,6",
#   "prec": "0,0",
#   "tmin": "17,5",
#   "horatmin": "05:20",
#   "tmax": "21,8",
#   "horatmax": "10:10",
#   "dir": "05",
#   "velmedia": "1,7",
#   "racha": "6,4",
#   "horaracha": "Varias",
#   "sol": "0,8",
#   "presMax": "1023,0",
#   "horaPresMax": "23",
#   "presMin": "1016,8",
#   "horaPresMin": "03",
#   "hrMedia": "83",
#   "hrMax": "92",
#   "horaHrMax": "05:20",
#   "hrMin": "72",
#   "horaHrMin": "Varias"
# }

# %% [markdown]
# ## Paso 5: Procesamiento y Limpieza de Datos (Pipeline ETL)
#
# Los datos crudos de AEMET vienen completamente en formato de texto (strings). Además, la representación decimal utiliza la coma española (`,`) en lugar del punto (`.`), lo cual impide operaciones aritméticas en Pandas.
#
# Implementamos la función `limpiar_y_cargar_datos` que realiza el siguiente flujo de transformación:
# 1. Extrae los campos de interés de cada registro.
# 2. Convierte el campo `fecha` a tipo `datetime` de Pandas.
# 3. Normaliza las representaciones numéricas: reemplaza las comas por puntos en variables continuas y las convierte a tipo `float32` o `int` de forma segura.
# 4. Convierte las horas de temperaturas/presiones máximas y mínimas a objetos `datetime.time`, gestionando de forma robusta valores de texto anómalos como 'Varias' o nulos.
# 5. Limpia el campo de precipitación (`prec`), convirtiendo el valor especial "Ip" (inapreciable) a `0.0` para poder realizar cálculos y sumas acumuladas consistentes.

# %%
# Limpieza y preparación de los datos obtenidos
def limpiar_y_cargar_datos(datos_json):
    if not datos_json:
        return pd.DataFrame()
        
    datos_lista = []
    for dia in datos_json:
        datos_lista.append({
            "fecha": dia.get("fecha"),
            "indicativo": dia.get("indicativo"),
            "nombre": dia.get("nombre"),
            "provincia": dia.get("provincia"),
            "altitud": dia.get("altitud"),
            "tmed": dia.get("tmed"),
            "prec": dia.get("prec", "0,00"),
            "tmin": dia.get("tmin"),
            "horatmin": dia.get("horatmin"),
            "tmax": dia.get("tmax"),
            "horatmax": dia.get("horatmax"),
            "dir": dia.get("dir"),
            "velmedia": dia.get("velmedia"),
            "racha": dia.get("racha"),
            "horaracha": dia.get("horaracha"),
            "sol": dia.get("sol"),
            "presMax": dia.get("presMax"),
            "horaPresMax": dia.get("horaPresMax"),
            "presMin": dia.get("presMin"),
            "horaPresMin": dia.get("horaPresMin"),
            "hrMedia": dia.get("hrMedia"),
            "hrMax": dia.get("hrMax"),
            "horaHrMax": dia.get("horaHrMax"),
            "hrMin": dia.get("hrMin"),
            "horaHrMin": dia.get("horaHrMin")
        })

    df = pd.DataFrame(datos_lista)

    # 1. Ajustes básicos de tipos de datos
    df["fecha"] = pd.to_datetime(df["fecha"])
    df["indicativo"] = df["indicativo"].astype(str)
    df["nombre"] = df["nombre"].astype(str)
    df["provincia"] = df["provincia"].astype(str)
    df["altitud"] = pd.to_numeric(df["altitud"], errors="coerce")

    # Función para pasar números con coma (español) a float con punto
    def a_float(columna):
        if columna is None:
            return np.nan
        return columna.astype(str).str.replace(",", ".").replace("", "nan").astype(np.float32)

    # 2. Convertimos las columnas numéricas
    columnas_numericas = ["tmed", "tmin", "tmax", "velmedia", "racha", "sol", "presMax", "presMin", "hrMedia", "hrMax", "hrMin"]
    for col in columnas_numericas:
        if col in df.columns:
            df[col] = a_float(df[col])

    # 3. Arreglamos la precipitación (la API a veces devuelve "Ip" que significa inapreciable, la ponemos en 0.0)
    if "prec" in df.columns:
        df["prec"] = df["prec"].astype(str).str.replace("Ip", "0.0").str.replace(",", ".").replace("", "0.0")
        df["prec"] = pd.to_numeric(df["prec"], errors="coerce").astype(np.float32)

    # 4. Limpiamos horas y las pasamos a tipo time de python
    columnas_tiempo = ["horatmin", "horatmax", "horaHrMax", "horaHrMin"]
    for col in columnas_tiempo:
        if col in df.columns:
            df[col] = df[col].astype(str).replace(["Varias", "nan", "None", ""], np.nan)
            df[col] = pd.to_datetime(df[col], format="%H:%M", errors="coerce").dt.time

    # 5. Otras horas que vienen solo con la hora
    columnas_hora_sola = ["horaPresMax", "horaPresMin"]
    for col in columnas_hora_sola:
        if col in df.columns:
            df[col] = df[col].astype(str).replace(["Varias", "nan", "None", ""], np.nan)
            df[col] = pd.to_datetime(df[col], format="%H", errors="coerce").dt.time

    if "dir" in df.columns:
        df["dir"] = df["dir"].astype(str)
    if "horaracha" in df.columns:
        df["horaracha"] = df["horaracha"].astype(str)

    return df

# Probamos a limpiar los datos de prueba
df_prueba = limpiar_y_cargar_datos(climaticos_prueba)
print("Limpieza de prueba terminada!")
print("Tipos del DataFrame:")
df_prueba.info()
print("Muestra:")
display(df_prueba.head(5))
# Out:
# Limpieza de prueba terminada!
# Tipos del DataFrame:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fecha        15 non-null     datetime64[us]
#  1   indicativo   15 non-null     str
#  2   nombre       15 non-null     str
#  3   provincia    15 non-null     str
#  4   altitud      15 non-null     int64
#  5   tmed         15 non-null     float32
#  6   prec         15 non-null     float32
#  7   tmin         15 non-null     float32
#  8   horatmin     14 non-null     object
#  9   tmax         15 non-null     float32
#  10  horatmax     15 non-null     object
#  11  dir          15 non-null     str
#  12  velmedia     15 non-null     float32
#  13  racha        15 non-null     float32
#  14  horaracha    15 non-null     str
#  15  sol          15 non-null     float32
#  16  presMax      15 non-null     float32
#  17  horaPresMax  13 non-null     object
#  18  presMin      15 non-null     float32
#  19  horaPresMin  12 non-null     object
#  20  hrMedia      15 non-null     float32
#  21  hrMax        15 non-null     float32
#  22  horaHrMax    12 non-null     object
#  23  hrMin        15 non-null     float32
#  24  horaHrMin    11 non-null     object
# dtypes: datetime64[us](1), float32(12), int64(1), object(6), str(5)
# memory usage: 2.8+ KB
# Muestra:
#        fecha indicativo         nombre provincia  altitud       tmed  prec  \
# 0 2026-05-01       B228  PALMA, PUERTO  BALEARES        3  19.600000   0.0
# 1 2026-05-02       B228  PALMA, PUERTO  BALEARES        3  20.600000   0.0
# 2 2026-05-03       B228  PALMA, PUERTO  BALEARES        3  19.600000  27.6
# 3 2026-05-04       B228  PALMA, PUERTO  BALEARES        3  19.799999   0.0
# 4 2026-05-05       B228  PALMA, PUERTO  BALEARES        3  19.200001   0.0
#
#         tmin  horatmin       tmax  ...  sol      presMax  horaPresMax  \
# 0  17.500000  05:20:00  21.799999  ...  0.8  1023.000000     23:00:00
# 1  17.600000       NaT  23.600000  ...  6.8  1022.299988     00:00:00
# 2  16.200001  07:50:00  22.900000  ...  2.7  1017.299988     00:00:00
# 3  18.200001  02:20:00  21.299999  ...  8.5  1013.900024     00:00:00
# 4  16.700001  23:59:00  21.799999  ...  6.7  1012.700012     00:00:00
#
#        presMin horaPresMin  hrMedia  hrMax horaHrMax  hrMin horaHrMin
# 0  1016.799988    03:00:00     83.0   92.0  05:20:00   72.0       NaT
# 1  1017.299988         NaT     72.0   90.0  04:10:00   58.0  15:10:00
# 2  1012.400024    16:00:00     82.0   98.0  08:00:00   64.0  15:20:00
# 3  1011.200012    16:00:00     90.0   94.0       NaT   86.0  07:50:00
# 4  1009.299988    17:00:00     84.0   96.0  05:40:00   75.0       NaT
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Paso 6: Extracción Histórica Masiva con Control de Rate Limiting
#
# Para obtener un dataset consistente e histórico, se implementa un bucle recursivo que descarga datos año por año y mes por mes.
#
# **⚠️ IMPORTANTE - Límites de la API de AEMET:**
# AEMET limita estrictamente la cantidad de llamadas simultáneas. Si no se manejan pausas, la API responderá con errores `HTTP 429` (Demasiadas peticiones) o bloqueará el token de usuario.
# Para evitar esto, implementamos:
# 1. **Pausa de 60 segundos** entre cada año consultado.
# 2. **Pausa de 1.5 segundos** entre cada mes consultado.
# 3. **Pausa de 40 minutos** de seguridad si el tiempo total de ejecución supera los 5 minutos de forma continua.
# 4. **Saltado dinámico de meses futuros** para evitar llamadas inútiles sobre periodos que aún no han ocurrido.
#
# *Nota de control:* Por defecto, esta descarga está pre-configurada para extraer los **últimos 3 años** (2024-2026) para optimizar el tiempo de prueba de este notebook. Si deseas obtener la serie histórica completa de los últimos 10 años, simplemente modifica la variable `AÑOS_A_CONSULTAR = 10`.

# %%
from datetime import datetime, timedelta
import gc

# Ajustamos las fechas para la descarga histórica (10 años en bloques)
fecha_fin_global = datetime(2026, 5, 30)
DIAS_A_CONSULTAR = 3650  # 10 años
fecha_inicio_global = fecha_fin_global - timedelta(days=DIAS_A_CONSULTAR - 1)

# Carpetas de salida
OUTPUT_CSV_DIR = BASE_DIR / 'sheets' / 'csv'
OUTPUT_XLSX_DIR = BASE_DIR / 'sheets' / 'xlsx'
OUTPUT_CSV_DIR.mkdir(parents=True, exist_ok=True)
OUTPUT_XLSX_DIR.mkdir(parents=True, exist_ok=True)

año_inicio = fecha_inicio_global.year
año_fin = fecha_fin_global.year

print(f"Empezando la descarga masiva por años desde {año_inicio} hasta {año_fin}...")

for anio in range(año_fin, año_inicio - 1, -1):
    print("\n-----------------------------------------")
    print(f"Procesando el año: {anio}")
    print("-----------------------------------------")
    
    ini_anio = max(datetime(anio, 1, 1), fecha_inicio_global)
    fin_anio = min(datetime(anio, 12, 31), fecha_fin_global)
    
    df_anio = pd.DataFrame()
    fecha_actual = fin_anio
    
    lote_size = 15  # Descargamos en bloques de 15 días
    dias_anio_procesados = 0
    total_dias_anio = (fin_anio - ini_anio).days + 1
    
    print(f"Fechas para {anio}: de {ini_anio.strftime('%Y-%m-%d')} a {fin_anio.strftime('%Y-%m-%d')} ({total_dias_anio} días)")
    
    while dias_anio_procesados < total_dias_anio:
        dias_restantes = total_dias_anio - dias_anio_procesados
        dias_lote = min(lote_size, dias_restantes)
        
        fecha_ini_lote = fecha_actual - timedelta(days=dias_lote - 1)
        
        fecha_ini_str = fecha_ini_lote.strftime("%Y-%m-%dT00:00:00UTC")
        fecha_fin_str = fecha_actual.strftime("%Y-%m-%dT23:59:59UTC")
        
        print(f"Descargando bloque: {fecha_ini_str} a {fecha_fin_str}...")
        
        # Esperamos 2 segundos entre descargas para no pasarnos del límite de la API
        print("Pausa de 2 segundos...")
        time.sleep(2.0)
        
        datos_json = obtener_valores_climaticos_todas(fecha_ini_str, fecha_fin_str)
        
        if datos_json:
            df_lote = limpiar_y_cargar_datos(datos_json)
            df_anio = pd.concat([df_anio, df_lote], ignore_index=True)
            print(f"Ok, bloque descargado. Registros nuevos: {len(df_lote)}")
        else:
            print(f"Error en bloque de {fecha_ini_str} a {fecha_fin_str}")
            
        dias_anio_procesados += dias_lote
        fecha_actual = fecha_ini_lote - timedelta(days=1)
        
    # Guardamos el año completo y limpiamos memoria RAM
    if not df_anio.empty:
        # Ordenar por fecha cronológica más antigua a más reciente
        if 'fecha' in df_anio.columns:
            df_anio = df_anio.sort_values(by='fecha', ascending=True)
            
        csv_path = OUTPUT_CSV_DIR / f'climaticos_{anio}.csv'
        excel_path = OUTPUT_XLSX_DIR / f'climaticos_{anio}.xlsx'
        
        print(f"Guardando ficheros para el año {anio}...")
        try:
            # Guardamos en CSV
            df_anio.to_csv(csv_path, index=False)
            print(f"Guardado CSV en: {csv_path}")
            
            # Guardamos en Excel con un ExcelWriter
            with pd.ExcelWriter(excel_path, engine='openpyxl') as writer:
                df_anio.to_excel(writer, index=False)
            print(f"Guardado Excel en: {excel_path}")
        except Exception as e:
            print(f"Error al guardar los archivos de {anio}: {e}")
            
        # Forzamos la limpieza de RAM
        del df_anio
        gc.collect()
    else:
        print(f"No hay datos para el año {anio}, no guardamos nada.")

print("\n¡Descarga y exportación completadas!")
# Out:
# Empezando la descarga masiva por años desde 2016 hasta 2026...
#
# -----------------------------------------
# Procesando el año: 2026
# -----------------------------------------
# Fechas para 2026: de 2026-01-01 a 2026-05-30 (150 días)
# Descargando bloque: 2026-05-16T00:00:00UTC a 2026-05-30T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12270
# Descargando bloque: 2026-05-01T00:00:00UTC a 2026-05-15T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12241
# Descargando bloque: 2026-04-16T00:00:00UTC a 2026-04-30T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12375
# Descargando bloque: 2026-04-01T00:00:00UTC a 2026-04-15T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12499
# Descargando bloque: 2026-03-17T00:00:00UTC a 2026-03-31T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Intento 3: HTTP 429 (Muchas peticiones).
# Esperando 20.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12520
# Descargando bloque: 2026-03-02T00:00:00UTC a 2026-03-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12426
# Descargando bloque: 2026-02-15T00:00:00UTC a 2026-03-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12411
# Descargando bloque: 2026-01-31T00:00:00UTC a 2026-02-14T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12443
# Descargando bloque: 2026-01-16T00:00:00UTC a 2026-01-30T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12612
# Descargando bloque: 2026-01-01T00:00:00UTC a 2026-01-15T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12537
# Guardando ficheros para el año 2026...
# Guardado CSV en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\csv\climaticos_2026.csv
# Guardado Excel en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\xlsx\climaticos_2026.xlsx
#
# -----------------------------------------
# Procesando el año: 2025
# -----------------------------------------
# Fechas para 2025: de 2025-01-01 a 2025-12-31 (365 días)
# Descargando bloque: 2025-12-17T00:00:00UTC a 2025-12-31T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12638
# Descargando bloque: 2025-12-02T00:00:00UTC a 2025-12-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12670
# Descargando bloque: 2025-11-17T00:00:00UTC a 2025-12-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12725
# Descargando bloque: 2025-11-02T00:00:00UTC a 2025-11-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12732
# Descargando bloque: 2025-10-18T00:00:00UTC a 2025-11-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12780
# Descargando bloque: 2025-10-03T00:00:00UTC a 2025-10-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12809
# Descargando bloque: 2025-09-18T00:00:00UTC a 2025-10-02T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Intento 3: HTTP 429 (Muchas peticiones).
# Esperando 20.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12842
# Descargando bloque: 2025-09-03T00:00:00UTC a 2025-09-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12828
# Descargando bloque: 2025-08-19T00:00:00UTC a 2025-09-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12813
# Descargando bloque: 2025-08-04T00:00:00UTC a 2025-08-18T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12800
# Descargando bloque: 2025-07-20T00:00:00UTC a 2025-08-03T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12858
# Descargando bloque: 2025-07-05T00:00:00UTC a 2025-07-19T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1 fallido al descargar datos: 500
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12865
# Descargando bloque: 2025-06-20T00:00:00UTC a 2025-07-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12823
# Descargando bloque: 2025-06-05T00:00:00UTC a 2025-06-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12848
# Descargando bloque: 2025-05-21T00:00:00UTC a 2025-06-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12881
# Descargando bloque: 2025-05-06T00:00:00UTC a 2025-05-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12802
# Descargando bloque: 2025-04-21T00:00:00UTC a 2025-05-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12741
# Descargando bloque: 2025-04-06T00:00:00UTC a 2025-04-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12753
# Descargando bloque: 2025-03-22T00:00:00UTC a 2025-04-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12842
# Descargando bloque: 2025-03-07T00:00:00UTC a 2025-03-21T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1 fallido al descargar datos: 500
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12815
# Descargando bloque: 2025-02-20T00:00:00UTC a 2025-03-06T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12852
# Descargando bloque: 2025-02-05T00:00:00UTC a 2025-02-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12885
# Descargando bloque: 2025-01-21T00:00:00UTC a 2025-02-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12872
# Descargando bloque: 2025-01-06T00:00:00UTC a 2025-01-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12853
# Descargando bloque: 2025-01-01T00:00:00UTC a 2025-01-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 4263
# Guardando ficheros para el año 2025...
# Guardado CSV en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\csv\climaticos_2025.csv
# Guardado Excel en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\xlsx\climaticos_2025.xlsx
#
# -----------------------------------------
# Procesando el año: 2024
# -----------------------------------------
# Fechas para 2024: de 2024-01-01 a 2024-12-31 (366 días)
# Descargando bloque: 2024-12-17T00:00:00UTC a 2024-12-31T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12823
# Descargando bloque: 2024-12-02T00:00:00UTC a 2024-12-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12809
# Descargando bloque: 2024-11-17T00:00:00UTC a 2024-12-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12860
# Descargando bloque: 2024-11-02T00:00:00UTC a 2024-11-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12851
# Descargando bloque: 2024-10-18T00:00:00UTC a 2024-11-01T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12837
# Descargando bloque: 2024-10-03T00:00:00UTC a 2024-10-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12848
# Descargando bloque: 2024-09-18T00:00:00UTC a 2024-10-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12879
# Descargando bloque: 2024-09-03T00:00:00UTC a 2024-09-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12798
# Descargando bloque: 2024-08-19T00:00:00UTC a 2024-09-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12753
# Descargando bloque: 2024-08-04T00:00:00UTC a 2024-08-18T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12826
# Descargando bloque: 2024-07-20T00:00:00UTC a 2024-08-03T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12843
# Descargando bloque: 2024-07-05T00:00:00UTC a 2024-07-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12821
# Descargando bloque: 2024-06-20T00:00:00UTC a 2024-07-04T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12812
# Descargando bloque: 2024-06-05T00:00:00UTC a 2024-06-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12864
# Descargando bloque: 2024-05-21T00:00:00UTC a 2024-06-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12873
# Descargando bloque: 2024-05-06T00:00:00UTC a 2024-05-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12859
# Descargando bloque: 2024-04-21T00:00:00UTC a 2024-05-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12914
# Descargando bloque: 2024-04-06T00:00:00UTC a 2024-04-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12986
# Descargando bloque: 2024-03-22T00:00:00UTC a 2024-04-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12880
# Descargando bloque: 2024-03-07T00:00:00UTC a 2024-03-21T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12902
# Descargando bloque: 2024-02-21T00:00:00UTC a 2024-03-06T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12931
# Descargando bloque: 2024-02-06T00:00:00UTC a 2024-02-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12917
# Descargando bloque: 2024-01-22T00:00:00UTC a 2024-02-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12950
# Descargando bloque: 2024-01-07T00:00:00UTC a 2024-01-21T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12937
# Descargando bloque: 2024-01-01T00:00:00UTC a 2024-01-06T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 5178
# Guardando ficheros para el año 2024...
# Guardado CSV en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\csv\climaticos_2024.csv
# Guardado Excel en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\xlsx\climaticos_2024.xlsx
#
# -----------------------------------------
# Procesando el año: 2023
# -----------------------------------------
# Fechas para 2023: de 2023-01-01 a 2023-12-31 (365 días)
# Descargando bloque: 2023-12-17T00:00:00UTC a 2023-12-31T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12945
# Descargando bloque: 2023-12-02T00:00:00UTC a 2023-12-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12903
# Descargando bloque: 2023-11-17T00:00:00UTC a 2023-12-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12877
# Descargando bloque: 2023-11-02T00:00:00UTC a 2023-11-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12836
# Descargando bloque: 2023-10-18T00:00:00UTC a 2023-11-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12835
# Descargando bloque: 2023-10-03T00:00:00UTC a 2023-10-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12867
# Descargando bloque: 2023-09-18T00:00:00UTC a 2023-10-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12894
# Descargando bloque: 2023-09-03T00:00:00UTC a 2023-09-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12830
# Descargando bloque: 2023-08-19T00:00:00UTC a 2023-09-02T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1 fallido al descargar datos: 500
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12858
# Descargando bloque: 2023-08-04T00:00:00UTC a 2023-08-18T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12868
# Descargando bloque: 2023-07-20T00:00:00UTC a 2023-08-03T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12849
# Descargando bloque: 2023-07-05T00:00:00UTC a 2023-07-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12829
# Descargando bloque: 2023-06-20T00:00:00UTC a 2023-07-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12661
# Descargando bloque: 2023-06-05T00:00:00UTC a 2023-06-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12602
# Descargando bloque: 2023-05-21T00:00:00UTC a 2023-06-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12532
# Descargando bloque: 2023-05-06T00:00:00UTC a 2023-05-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12621
# Descargando bloque: 2023-04-21T00:00:00UTC a 2023-05-05T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12697
# Descargando bloque: 2023-04-06T00:00:00UTC a 2023-04-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12741
# Descargando bloque: 2023-03-22T00:00:00UTC a 2023-04-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12741
# Descargando bloque: 2023-03-07T00:00:00UTC a 2023-03-21T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12745
# Descargando bloque: 2023-02-20T00:00:00UTC a 2023-03-06T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12744
# Descargando bloque: 2023-02-05T00:00:00UTC a 2023-02-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12745
# Descargando bloque: 2023-01-21T00:00:00UTC a 2023-02-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12706
# Descargando bloque: 2023-01-06T00:00:00UTC a 2023-01-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12650
# Descargando bloque: 2023-01-01T00:00:00UTC a 2023-01-05T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 4229
# Guardando ficheros para el año 2023...
# Guardado CSV en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\csv\climaticos_2023.csv
# Guardado Excel en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\xlsx\climaticos_2023.xlsx
#
# -----------------------------------------
# Procesando el año: 2022
# -----------------------------------------
# Fechas para 2022: de 2022-01-01 a 2022-12-31 (365 días)
# Descargando bloque: 2022-12-17T00:00:00UTC a 2022-12-31T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12641
# Descargando bloque: 2022-12-02T00:00:00UTC a 2022-12-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12623
# Descargando bloque: 2022-11-17T00:00:00UTC a 2022-12-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12677
# Descargando bloque: 2022-11-02T00:00:00UTC a 2022-11-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12620
# Descargando bloque: 2022-10-18T00:00:00UTC a 2022-11-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12621
# Descargando bloque: 2022-10-03T00:00:00UTC a 2022-10-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12660
# Descargando bloque: 2022-09-18T00:00:00UTC a 2022-10-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12653
# Descargando bloque: 2022-09-03T00:00:00UTC a 2022-09-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12631
# Descargando bloque: 2022-08-19T00:00:00UTC a 2022-09-02T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1 fallido al descargar datos: 500
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12647
# Descargando bloque: 2022-08-04T00:00:00UTC a 2022-08-18T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12647
# Descargando bloque: 2022-07-20T00:00:00UTC a 2022-08-03T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12634
# Descargando bloque: 2022-07-05T00:00:00UTC a 2022-07-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12664
# Descargando bloque: 2022-06-20T00:00:00UTC a 2022-07-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12636
# Descargando bloque: 2022-06-05T00:00:00UTC a 2022-06-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12628
# Descargando bloque: 2022-05-21T00:00:00UTC a 2022-06-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12641
# Descargando bloque: 2022-05-06T00:00:00UTC a 2022-05-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12650
# Descargando bloque: 2022-04-21T00:00:00UTC a 2022-05-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12670
# Descargando bloque: 2022-04-06T00:00:00UTC a 2022-04-20T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12647
# Descargando bloque: 2022-03-22T00:00:00UTC a 2022-04-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12676
# Descargando bloque: 2022-03-07T00:00:00UTC a 2022-03-21T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12737
# Descargando bloque: 2022-02-20T00:00:00UTC a 2022-03-06T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12749
# Descargando bloque: 2022-02-05T00:00:00UTC a 2022-02-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12730
# Descargando bloque: 2022-01-21T00:00:00UTC a 2022-02-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12717
# Descargando bloque: 2022-01-06T00:00:00UTC a 2022-01-20T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Intento 3: HTTP 429 (Muchas peticiones).
# Esperando 20.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12723
# Descargando bloque: 2022-01-01T00:00:00UTC a 2022-01-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 4263
# Guardando ficheros para el año 2022...
# Guardado CSV en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\csv\climaticos_2022.csv
# Guardado Excel en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\xlsx\climaticos_2022.xlsx
#
# -----------------------------------------
# Procesando el año: 2021
# -----------------------------------------
# Fechas para 2021: de 2021-01-01 a 2021-12-31 (365 días)
# Descargando bloque: 2021-12-17T00:00:00UTC a 2021-12-31T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12775
# Descargando bloque: 2021-12-02T00:00:00UTC a 2021-12-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12681
# Descargando bloque: 2021-11-17T00:00:00UTC a 2021-12-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12707
# Descargando bloque: 2021-11-02T00:00:00UTC a 2021-11-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12707
# Descargando bloque: 2021-10-18T00:00:00UTC a 2021-11-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12723
# Descargando bloque: 2021-10-03T00:00:00UTC a 2021-10-17T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Intento 3: Error de red/conexión: HTTPSConnectionPool(host='opendata.aemet.es', port=443): Max retries exceeded with url: /opendata/api/valores/climatologicos/diarios/datos/fechaini/2021-10-03T00:00:00UTC/fechafin/2021-10-17T23:59:59UTC/todasestaciones (Caused by NameResolutionError("HTTPSConnection(host='opendata.aemet.es', port=443): Failed to resolve 'opendata.aemet.es' ([Errno 11001] getaddrinfo failed)"))
# Esperando 20.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12674
# Descargando bloque: 2021-09-18T00:00:00UTC a 2021-10-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12607
# Descargando bloque: 2021-09-03T00:00:00UTC a 2021-09-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12600
# Descargando bloque: 2021-08-19T00:00:00UTC a 2021-09-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12649
# Descargando bloque: 2021-08-04T00:00:00UTC a 2021-08-18T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12637
# Descargando bloque: 2021-07-20T00:00:00UTC a 2021-08-03T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12621
# Descargando bloque: 2021-07-05T00:00:00UTC a 2021-07-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12556
# Descargando bloque: 2021-06-20T00:00:00UTC a 2021-07-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12493
# Descargando bloque: 2021-06-05T00:00:00UTC a 2021-06-19T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12537
# Descargando bloque: 2021-05-21T00:00:00UTC a 2021-06-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12582
# Descargando bloque: 2021-05-06T00:00:00UTC a 2021-05-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12579
# Descargando bloque: 2021-04-21T00:00:00UTC a 2021-05-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12612
# Descargando bloque: 2021-04-06T00:00:00UTC a 2021-04-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12606
# Descargando bloque: 2021-03-22T00:00:00UTC a 2021-04-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12603
# Descargando bloque: 2021-03-07T00:00:00UTC a 2021-03-21T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12599
# Descargando bloque: 2021-02-20T00:00:00UTC a 2021-03-06T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12640
# Descargando bloque: 2021-02-05T00:00:00UTC a 2021-02-19T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12523
# Descargando bloque: 2021-01-21T00:00:00UTC a 2021-02-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12496
# Descargando bloque: 2021-01-06T00:00:00UTC a 2021-01-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12490
# Descargando bloque: 2021-01-01T00:00:00UTC a 2021-01-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 4171
# Guardando ficheros para el año 2021...
# Guardado CSV en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\csv\climaticos_2021.csv
# Guardado Excel en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\xlsx\climaticos_2021.xlsx
#
# -----------------------------------------
# Procesando el año: 2020
# -----------------------------------------
# Fechas para 2020: de 2020-01-01 a 2020-12-31 (366 días)
# Descargando bloque: 2020-12-17T00:00:00UTC a 2020-12-31T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12563
# Descargando bloque: 2020-12-02T00:00:00UTC a 2020-12-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12544
# Descargando bloque: 2020-11-17T00:00:00UTC a 2020-12-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12494
# Descargando bloque: 2020-11-02T00:00:00UTC a 2020-11-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12531
# Descargando bloque: 2020-10-18T00:00:00UTC a 2020-11-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12496
# Descargando bloque: 2020-10-03T00:00:00UTC a 2020-10-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12494
# Descargando bloque: 2020-09-18T00:00:00UTC a 2020-10-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12413
# Descargando bloque: 2020-09-03T00:00:00UTC a 2020-09-17T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1 fallido al descargar datos: 500
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Intento 3: HTTP 429 (Muchas peticiones).
# Esperando 20.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12415
# Descargando bloque: 2020-08-19T00:00:00UTC a 2020-09-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12388
# Descargando bloque: 2020-08-04T00:00:00UTC a 2020-08-18T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12293
# Descargando bloque: 2020-07-20T00:00:00UTC a 2020-08-03T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12316
# Descargando bloque: 2020-07-05T00:00:00UTC a 2020-07-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12318
# Descargando bloque: 2020-06-20T00:00:00UTC a 2020-07-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12350
# Descargando bloque: 2020-06-05T00:00:00UTC a 2020-06-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12279
# Descargando bloque: 2020-05-21T00:00:00UTC a 2020-06-04T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12344
# Descargando bloque: 2020-05-06T00:00:00UTC a 2020-05-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12334
# Descargando bloque: 2020-04-21T00:00:00UTC a 2020-05-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12341
# Descargando bloque: 2020-04-06T00:00:00UTC a 2020-04-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12377
# Descargando bloque: 2020-03-22T00:00:00UTC a 2020-04-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12352
# Descargando bloque: 2020-03-07T00:00:00UTC a 2020-03-21T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12444
# Descargando bloque: 2020-02-21T00:00:00UTC a 2020-03-06T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12517
# Descargando bloque: 2020-02-06T00:00:00UTC a 2020-02-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12541
# Descargando bloque: 2020-01-22T00:00:00UTC a 2020-02-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12503
# Descargando bloque: 2020-01-07T00:00:00UTC a 2020-01-21T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12512
# Descargando bloque: 2020-01-01T00:00:00UTC a 2020-01-06T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 4992
# Guardando ficheros para el año 2020...
# Guardado CSV en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\csv\climaticos_2020.csv
# Guardado Excel en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\xlsx\climaticos_2020.xlsx
#
# -----------------------------------------
# Procesando el año: 2019
# -----------------------------------------
# Fechas para 2019: de 2019-01-01 a 2019-12-31 (365 días)
# Descargando bloque: 2019-12-17T00:00:00UTC a 2019-12-31T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12403
# Descargando bloque: 2019-12-02T00:00:00UTC a 2019-12-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12474
# Descargando bloque: 2019-11-17T00:00:00UTC a 2019-12-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12400
# Descargando bloque: 2019-11-02T00:00:00UTC a 2019-11-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12374
# Descargando bloque: 2019-10-18T00:00:00UTC a 2019-11-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12425
# Descargando bloque: 2019-10-03T00:00:00UTC a 2019-10-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12329
# Descargando bloque: 2019-09-18T00:00:00UTC a 2019-10-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12325
# Descargando bloque: 2019-09-03T00:00:00UTC a 2019-09-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12374
# Descargando bloque: 2019-08-19T00:00:00UTC a 2019-09-02T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12404
# Descargando bloque: 2019-08-04T00:00:00UTC a 2019-08-18T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12452
# Descargando bloque: 2019-07-20T00:00:00UTC a 2019-08-03T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12386
# Descargando bloque: 2019-07-05T00:00:00UTC a 2019-07-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12349
# Descargando bloque: 2019-06-20T00:00:00UTC a 2019-07-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12443
# Descargando bloque: 2019-06-05T00:00:00UTC a 2019-06-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12460
# Descargando bloque: 2019-05-21T00:00:00UTC a 2019-06-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12501
# Descargando bloque: 2019-05-06T00:00:00UTC a 2019-05-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12504
# Descargando bloque: 2019-04-21T00:00:00UTC a 2019-05-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12466
# Descargando bloque: 2019-04-06T00:00:00UTC a 2019-04-20T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Intento 3: HTTP 429 (Muchas peticiones).
# Esperando 20.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12444
# Descargando bloque: 2019-03-22T00:00:00UTC a 2019-04-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12472
# Descargando bloque: 2019-03-07T00:00:00UTC a 2019-03-21T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12441
# Descargando bloque: 2019-02-20T00:00:00UTC a 2019-03-06T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12462
# Descargando bloque: 2019-02-05T00:00:00UTC a 2019-02-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12453
# Descargando bloque: 2019-01-21T00:00:00UTC a 2019-02-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12379
# Descargando bloque: 2019-01-06T00:00:00UTC a 2019-01-20T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1 fallido al descargar datos: 500
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12417
# Descargando bloque: 2019-01-01T00:00:00UTC a 2019-01-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 4142
# Guardando ficheros para el año 2019...
# Guardado CSV en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\csv\climaticos_2019.csv
# Guardado Excel en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\xlsx\climaticos_2019.xlsx
#
# -----------------------------------------
# Procesando el año: 2018
# -----------------------------------------
# Fechas para 2018: de 2018-01-01 a 2018-12-31 (365 días)
# Descargando bloque: 2018-12-17T00:00:00UTC a 2018-12-31T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: Error de red/conexión: HTTPSConnectionPool(host='opendata.aemet.es', port=443): Max retries exceeded with url: /opendata/api/valores/climatologicos/diarios/datos/fechaini/2018-12-17T00:00:00UTC/fechafin/2018-12-31T23:59:59UTC/todasestaciones (Caused by NameResolutionError("HTTPSConnection(host='opendata.aemet.es', port=443): Failed to resolve 'opendata.aemet.es' ([Errno 11001] getaddrinfo failed)"))
# Esperando 10.0 segundos antes de reintentar...
# Intento 3: Error de red/conexión: HTTPSConnectionPool(host='opendata.aemet.es', port=443): Max retries exceeded with url: /opendata/api/valores/climatologicos/diarios/datos/fechaini/2018-12-17T00:00:00UTC/fechafin/2018-12-31T23:59:59UTC/todasestaciones (Caused by NameResolutionError("HTTPSConnection(host='opendata.aemet.es', port=443): Failed to resolve 'opendata.aemet.es' ([Errno 11001] getaddrinfo failed)"))
# Esperando 20.0 segundos antes de reintentar...
# Intento 4: HTTP 429 (Muchas peticiones).
# Esperando 40.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12425
# Descargando bloque: 2018-12-02T00:00:00UTC a 2018-12-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12405
# Descargando bloque: 2018-11-17T00:00:00UTC a 2018-12-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12418
# Descargando bloque: 2018-11-02T00:00:00UTC a 2018-11-16T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1 fallido al descargar datos: 500
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Intento 3: HTTP 429 (Muchas peticiones).
# Esperando 20.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12398
# Descargando bloque: 2018-10-18T00:00:00UTC a 2018-11-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12321
# Descargando bloque: 2018-10-03T00:00:00UTC a 2018-10-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12323
# Descargando bloque: 2018-09-18T00:00:00UTC a 2018-10-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12322
# Descargando bloque: 2018-09-03T00:00:00UTC a 2018-09-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12280
# Descargando bloque: 2018-08-19T00:00:00UTC a 2018-09-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12398
# Descargando bloque: 2018-08-04T00:00:00UTC a 2018-08-18T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12386
# Descargando bloque: 2018-07-20T00:00:00UTC a 2018-08-03T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12339
# Descargando bloque: 2018-07-05T00:00:00UTC a 2018-07-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12253
# Descargando bloque: 2018-06-20T00:00:00UTC a 2018-07-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12330
# Descargando bloque: 2018-06-05T00:00:00UTC a 2018-06-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12364
# Descargando bloque: 2018-05-21T00:00:00UTC a 2018-06-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12267
# Descargando bloque: 2018-05-06T00:00:00UTC a 2018-05-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12318
# Descargando bloque: 2018-04-21T00:00:00UTC a 2018-05-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12288
# Descargando bloque: 2018-04-06T00:00:00UTC a 2018-04-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12263
# Descargando bloque: 2018-03-22T00:00:00UTC a 2018-04-05T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Intento 3: HTTP 429 (Muchas peticiones).
# Esperando 20.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12310
# Descargando bloque: 2018-03-07T00:00:00UTC a 2018-03-21T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12309
# Descargando bloque: 2018-02-20T00:00:00UTC a 2018-03-06T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12346
# Descargando bloque: 2018-02-05T00:00:00UTC a 2018-02-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12318
# Descargando bloque: 2018-01-21T00:00:00UTC a 2018-02-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12367
# Descargando bloque: 2018-01-06T00:00:00UTC a 2018-01-20T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Intento 3: HTTP 429 (Muchas peticiones).
# Esperando 20.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12333
# Descargando bloque: 2018-01-01T00:00:00UTC a 2018-01-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 4118
# Guardando ficheros para el año 2018...
# Guardado CSV en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\csv\climaticos_2018.csv
# Guardado Excel en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\xlsx\climaticos_2018.xlsx
#
# -----------------------------------------
# Procesando el año: 2017
# -----------------------------------------
# Fechas para 2017: de 2017-01-01 a 2017-12-31 (365 días)
# Descargando bloque: 2017-12-17T00:00:00UTC a 2017-12-31T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12342
# Descargando bloque: 2017-12-02T00:00:00UTC a 2017-12-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12282
# Descargando bloque: 2017-11-17T00:00:00UTC a 2017-12-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12345
# Descargando bloque: 2017-11-02T00:00:00UTC a 2017-11-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12364
# Descargando bloque: 2017-10-18T00:00:00UTC a 2017-11-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12344
# Descargando bloque: 2017-10-03T00:00:00UTC a 2017-10-17T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Intento 3: HTTP 429 (Muchas peticiones).
# Esperando 20.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12392
# Descargando bloque: 2017-09-18T00:00:00UTC a 2017-10-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12382
# Descargando bloque: 2017-09-03T00:00:00UTC a 2017-09-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12405
# Descargando bloque: 2017-08-19T00:00:00UTC a 2017-09-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12362
# Descargando bloque: 2017-08-04T00:00:00UTC a 2017-08-18T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12371
# Descargando bloque: 2017-07-20T00:00:00UTC a 2017-08-03T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12377
# Descargando bloque: 2017-07-05T00:00:00UTC a 2017-07-19T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1 fallido al descargar datos: 500
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12367
# Descargando bloque: 2017-06-20T00:00:00UTC a 2017-07-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12342
# Descargando bloque: 2017-06-05T00:00:00UTC a 2017-06-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12349
# Descargando bloque: 2017-05-21T00:00:00UTC a 2017-06-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12278
# Descargando bloque: 2017-05-06T00:00:00UTC a 2017-05-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12359
# Descargando bloque: 2017-04-21T00:00:00UTC a 2017-05-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12310
# Descargando bloque: 2017-04-06T00:00:00UTC a 2017-04-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12346
# Descargando bloque: 2017-03-22T00:00:00UTC a 2017-04-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12336
# Descargando bloque: 2017-03-07T00:00:00UTC a 2017-03-21T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12371
# Descargando bloque: 2017-02-20T00:00:00UTC a 2017-03-06T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12359
# Descargando bloque: 2017-02-05T00:00:00UTC a 2017-02-19T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12310
# Descargando bloque: 2017-01-21T00:00:00UTC a 2017-02-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12274
# Descargando bloque: 2017-01-06T00:00:00UTC a 2017-01-20T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12330
# Descargando bloque: 2017-01-01T00:00:00UTC a 2017-01-05T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 4115
# Guardando ficheros para el año 2017...
# Guardado CSV en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\csv\climaticos_2017.csv
# Guardado Excel en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\xlsx\climaticos_2017.xlsx
#
# -----------------------------------------
# Procesando el año: 2016
# -----------------------------------------
# Fechas para 2016: de 2016-06-02 a 2016-12-31 (213 días)
# Descargando bloque: 2016-12-17T00:00:00UTC a 2016-12-31T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12241
# Descargando bloque: 2016-12-02T00:00:00UTC a 2016-12-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12222
# Descargando bloque: 2016-11-17T00:00:00UTC a 2016-12-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12154
# Descargando bloque: 2016-11-02T00:00:00UTC a 2016-11-16T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12174
# Descargando bloque: 2016-10-18T00:00:00UTC a 2016-11-01T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12209
# Descargando bloque: 2016-10-03T00:00:00UTC a 2016-10-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12214
# Descargando bloque: 2016-09-18T00:00:00UTC a 2016-10-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12238
# Descargando bloque: 2016-09-03T00:00:00UTC a 2016-09-17T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12241
# Descargando bloque: 2016-08-19T00:00:00UTC a 2016-09-02T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12204
# Descargando bloque: 2016-08-04T00:00:00UTC a 2016-08-18T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12235
# Descargando bloque: 2016-07-20T00:00:00UTC a 2016-08-03T23:59:59UTC...
# Pausa de 2 segundos...
# Intento 1: HTTP 429 (Muchas peticiones).
# Esperando 5.0 segundos antes de reintentar...
# Intento 2: HTTP 429 (Muchas peticiones).
# Esperando 10.0 segundos antes de reintentar...
# Ok, bloque descargado. Registros nuevos: 12270
# Descargando bloque: 2016-07-05T00:00:00UTC a 2016-07-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12215
# Descargando bloque: 2016-06-20T00:00:00UTC a 2016-07-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12237
# Descargando bloque: 2016-06-05T00:00:00UTC a 2016-06-19T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 12274
# Descargando bloque: 2016-06-02T00:00:00UTC a 2016-06-04T23:59:59UTC...
# Pausa de 2 segundos...
# Ok, bloque descargado. Registros nuevos: 2446
# Guardando ficheros para el año 2016...
# Guardado CSV en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\csv\climaticos_2016.csv
# Guardado Excel en: C:\curso_hack_boss\Proyecto_AEMET\grupo-aemet\Truji\sheets\xlsx\climaticos_2016.xlsx
#
# ¡Descarga y exportación completadas!

# %% [markdown]
# ## Paso 7: Verificación de los Archivos Físicos Generados
#
# Para validar que la exportación anual y segmentada se ha completado correctamente en disco, en esta sección listamos el contenido de los directorios de salida  y , mostrando el tamaño ocupado por cada archivo generado.

# %%
# Comprobamos los archivos creados en el disco y su tamaño
OUTPUT_CSV_DIR = BASE_DIR / 'sheets' / 'csv'
OUTPUT_XLSX_DIR = BASE_DIR / 'sheets' / 'xlsx'

print("Archivos CSV creados:")
if OUTPUT_CSV_DIR.exists():
    for f in sorted(OUTPUT_CSV_DIR.glob('climaticos_*')):
        size_mb = f.stat().st_size / (1024 * 1024)
        print(f" - csv/{f.name} ({size_mb:.2f} MB)")
else:
    print("El directorio de CSVs no existe.")

print("\nArchivos Excel creados:")
if OUTPUT_XLSX_DIR.exists():
    for f in sorted(OUTPUT_XLSX_DIR.glob('climaticos_*')):
        size_mb = f.stat().st_size / (1024 * 1024)
        print(f" - xlsx/{f.name} ({size_mb:.2f} MB)")
else:
    print("El directorio de Excels no existe.")
# Out:
# Archivos CSV creados:
#  - csv/climaticos_2016.csv (22.41 MB)
#  - csv/climaticos_2017.csv (38.89 MB)
#  - csv/climaticos_2018.csv (38.71 MB)
#  - csv/climaticos_2019.csv (39.24 MB)
#  - csv/climaticos_2020.csv (39.23 MB)
#  - csv/climaticos_2021.csv (39.81 MB)
#  - csv/climaticos_2022.csv (40.07 MB)
#  - csv/climaticos_2023.csv (40.51 MB)
#  - csv/climaticos_2024.csv (40.91 MB)
#  - csv/climaticos_2025.csv (40.63 MB)
#  - csv/climaticos_2026.csv (16.20 MB)
#
# Archivos Excel creados:
#  - xlsx/climaticos_2016.xlsx (22.39 MB)
#  - xlsx/climaticos_2017.xlsx (38.89 MB)
#  - xlsx/climaticos_2018.xlsx (38.86 MB)
#  - xlsx/climaticos_2019.xlsx (39.21 MB)
#  - xlsx/climaticos_2020.xlsx (39.23 MB)
#  - xlsx/climaticos_2021.xlsx (39.77 MB)
#  - xlsx/climaticos_2022.xlsx (39.98 MB)
#  - xlsx/climaticos_2023.xlsx (40.35 MB)
#  - xlsx/climaticos_2024.xlsx (40.78 MB)
#  - xlsx/climaticos_2025.xlsx (40.52 MB)
#  - xlsx/climaticos_2026.xlsx (16.09 MB)

# %% [markdown]
# ## ℹ️ Nota sobre la Variabilidad en el Número de Estaciones (Idemas) por Lote
#
# Es común observar que, aunque el inventario maestro de AEMET reporta aproximadamente **920 estaciones activas**, el número de registros diarios reales por lote no equivale exactamente a `920 estaciones × N días`.
#
# Por ejemplo, en un lote de 15 días (como del 16 al 30 de mayo), se obtienen unos **12,176 registros**, lo que equivale a un promedio de **~812 estaciones diarias** con reporte de datos, en lugar de las 920 teóricas.
#
# ### ¿A qué se debe esta diferencia?
# 1. **Estaciones inactivas o en mantenimiento:** Algunas estaciones pueden sufrir fallos de comunicación, averías en sensores o estar en periodos de mantenimiento programado.
# 2. **Validación y desfase temporal de datos:** AEMET somete los datos climatológicos a controles de calidad antes de publicarlos en la API OpenData. Las estaciones de publicación reciente o secundarias pueden tardar más en volcar sus datos.
# 3. **Altas y bajas en la red:** El inventario incluye estaciones históricas o de alta reciente que no necesariamente reportan en la horquilla temporal consultada.
# 4. **Filtros de datos nulos:** Durante el proceso de ingesta, aquellos registros que no contienen lecturas válidas o están totalmente vacíos para los días del lote son descartados o no transmitidos por la propia API.
