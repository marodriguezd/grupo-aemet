# %%
import pandas as pd 

df = pd.read_csv("./sheets/csv/climaticos_2016.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 173574 entries, 0 to 173573
# Data columns (total 25 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   fecha        173574 non-null  str
#  1   indicativo   173574 non-null  str
#  2   nombre       173574 non-null  str
#  3   provincia    173574 non-null  str
#  4   altitud      173574 non-null  int64
#  5   tmed         169409 non-null  float64
#  6   prec         173545 non-null  float64
#  7   tmin         169445 non-null  float64
#  8   horatmin     157063 non-null  str
#  9   tmax         169475 non-null  float64
#  10  horatmax     164369 non-null  str
#  11  dir          139891 non-null  float64
#  12  velmedia     140708 non-null  float64
#  13  racha        139898 non-null  float64
#  14  horaracha    139887 non-null  str
#  15  sol          30921 non-null   float64
#  16  presMax      45830 non-null   float64
#  17  horaPresMax  30464 non-null   str
# ...
