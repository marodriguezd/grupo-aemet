# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

import requests
import psycopg
from urllib import response
import json
import pickle
import bs4
from time import sleep
from time import time

# %% [markdown]
# ### AEMET
#
#
# **ETL**
# -------
#
#
# DESCARGA DE DATOS DESDE API AEMT

# %%
fechaini: str = "2023-01-01"
fechafin: str = "2023-01-31"


base_url: str = "https://opendata.aemet.es/opendata/api/"
endpoint_latest: str = "valores/climatologicos/inventarioestaciones/todasestaciones"
#ValoresClimatologicosApi.md#inventario_de_estaciones__valores_climatolgicos_)
apikey_aemet = "eyJzdWIiOiJ0Ymwuc2Vydi5saW1waWV6YUBnbWFpbC5jb20iLCJqdGkiOiI2ZjY2ZTc3Zi1iMjA3LTQwMWYtOTY3Mi01NDQ3Y2JmNjkzYTMiLCJpc3MiOiJBRU1FVCIsImlhdCI6MTc3OTk4Mzk5NiwidXNlcklkIjoiNmY2NmU3N2YtYjIwNy00MDFmLTk2NzItNTQ0N2NiZjY5M2EzIiwicm9sZSI6IiJ9.bxOGhcPh9jopiT35pOmnR9Q0TXQHNIVcXZObjsvxgiM.vOm_hOV2KXvjK1Bs2M2XQaXdf0LhVAMmJX_sH59imJw"
url: str = f"{base_url}{endpoint_latest}"
headers = {"accept": "application/json", "cache-control": "no-cache", "api_key": apikey_aemet}
    

url
# Out:
# 'https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones'

# %%
try:
    respuesta: requests.Response = requests.get(url = url, headers = headers)
    print(respuesta.status_code)
    if respuesta.status_code == 200:
        print(respuesta.json())
   
        
except requests.exceptions.RequestException as e:
    print(f"Error en la solicitud: {e}")
# Out:
# 401

# %%
url =  "https://opendata.aemet.es/opendata/sh/6495d589"

response: requests.Response = requests.get(url = url)

print(response.json())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 url =  "https://opendata.aemet.es/opendata/sh/6495d589"
#       2
# ----> 3 response: requests.Response = requests.get(url = url)
#       4
#       5 print(response.json())
#
# File ~/Escritorio/proyecto-2/.venv/lib/python3.12/site-packages/requests/api.py:87, in get(url, params, **kwargs)
#      74 def get(
#      75     url: _t.UriType, params: _t.ParamsType = None, **kwargs: Unpack[_t.GetKwargs]
#      76 ) -> Response:
#      77     r"""Sends a GET request.
#      78
#      79     :param url: URL for the new :class:`Request` object.
#    (...)     84     :rtype: requests.Response
#      85     """
# ---> 87     return request("get", url, params=params, **kwargs)
#
# File ~/Escritorio/proyecto-2/.venv/lib/python3.12/site-packages/requests/api.py:71, in request(method, url, **kwargs)
# ...

# %%
fechaIniStr: str = 2026-5-1
fechaFinStr: str = 2026-5-29

#https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2016-01-01/fechafin/2026-05-29/todasestaciones
endpoint: str = "/api/valores/climatologicos/diarios/datos/fechaini/{fechaIniStr}/fechafin/{fechaFinStr}/todasestaciones"
#ValoresClimatologicosApi.md#inventario_de_estaciones__valores_climatolgicos_)
apikey_aemet = "eyJzdWIiOiJ0Ymwuc2Vydi5saW1waWV6YUBnbWFpbC5jb20iLCJqdGkiOiI2ZjY2ZTc3Zi1iMjA3LTQwMWYtOTY3Mi01NDQ3Y2JmNjkzYTMiLCJpc3MiOiJBRU1FVCIsImlhdCI6MTc3OTk4Mzk5NiwidXNlcklkIjoiNmY2NmU3N2YtYjIwNy00MDFmLTk2NzItNTQ0N2NiZjY5M2EzIiwicm9sZSI6IiJ9.bxOGhcPh9jopiT35pOmnR9Q0TXQHNIVcXZObjsvxgiM.vOm_hOV2KXvjK1Bs2M2XQaXdf0LhVAMmJX_sH59imJw"
url: str = f"{url}{endpoint}"
headers = {"accept": "application/json", "cache-control": "no-cache", "api_key": apikey_aemet}
    

url
# Out:
# 'https://opendata.aemet.es/opendata/sh/6495d589/api/valores/climatologicos/diarios/datos/fechaini/{fechaIniStr}/fechafin/{fechaFinStr}/todasestaciones/api/valores/climatologicos/diarios/datos/fechaini/{fechaIniStr}/fechafin/{fechaFinStr}/todasestaciones/api/valores/climatologicos/diarios/datos/fechaini/{fechaIniStr}/fechafin/{fechaFinStr}/todasestaciones'

# %%
try:
    respuesta: requests.Response = requests.get(url = url, headers = headers)
    print(respuesta.status_code)
    if respuesta.status_code == 200:
        print(respuesta.json())
   
        
except requests.exceptions.RequestException as e:
    print(f"Error en la solicitud: {e}")
# Out:
# 404
